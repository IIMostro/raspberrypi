# %% [markdown]
# ## ESP-32 CAM 编译固件

# %% [markdown]
# ### 接口连接
# |USB UART|ESP32-CAM|
# |---|---|
# |TX|U0R|
# |RX|U0T|
# |DTR|IO0|
# |5V|5V|
# |GND|GND|

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [固件地址](https://github.com/tsaarni/micropython-with-esp32-cam)

# %% [markdown]
# [固件下载](https://link.juejin.cn/?target=https%3A%2F%2Fgithub.com%2Ftsaarni%2Fesp32-micropython-webcam%2Freleases%2Fdownload%2F2019-02-24%2Fmicropython-esp32-ov2640-firmware.tar.gz)

# %% [markdown]
# ### 擦除 esptool.py --chip esp32 --port  erase_flash
# ### 烧录
